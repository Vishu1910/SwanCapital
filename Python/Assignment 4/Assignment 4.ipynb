# %% [markdown]
# 1.Using the same Dmart file, calculate the weekly returns for the entire year
#
# 2.Populate a table of returns with week number of month(1,2,3,4,5) and month name
#
# Please note:
# 1.Week starts from Monday
# 2. Use while loop to loop through the dataframe and not any form of groupby, directly or indirectly
# 3. You buy at the open of the first day of the week and sell at the close of the last day of week
# 4. If the end of month falls on Wednesday, you exit your position on Wednesday close. New week of the new month starts from Thursday

# %%
import warnings
warnings.simplefilter(action='ignore',category=FutureWarning)

# %%
import pandas as pd
inputt=r'C:\Users\admin\Desktop\Dmart.csv'
df = pd.read_csv(inputt)

# %%
from datetime import datetime
df['Month']=pd.to_datetime(df['Date/Time']).dt.month
df['Date/Time']=pd.to_datetime(df['Date/Time']).dt.date
display(df)
# Out:
#            Ticker   Date/Time     Open      Low     High    Close  Month
# 0    DMART.EQ-NSE  2020-01-01  1849.70  1820.00  1867.00  1828.50      1
# 1    DMART.EQ-NSE  2020-01-02  1831.00  1815.00  1854.85  1824.20      1
# 2    DMART.EQ-NSE  2020-01-03  1827.00  1827.00  1853.00  1843.55      1
# 3    DMART.EQ-NSE  2020-01-06  1827.00  1780.00  1829.00  1789.90      1
# 4    DMART.EQ-NSE  2020-01-07  1805.00  1805.00  1837.50  1815.75      1
# ..            ...         ...      ...      ...      ...      ...    ...
# 247  DMART.EQ-NSE  2020-12-24  2661.85  2604.80  2700.00  2673.10     12
# 248  DMART.EQ-NSE  2020-12-28  2685.95  2655.00  2698.95  2678.00     12
# 249  DMART.EQ-NSE  2020-12-29  2690.00  2645.00  2694.70  2665.70     12
# 250  DMART.EQ-NSE  2020-12-30  2666.20  2642.35  2725.00  2680.30     12
# 251  DMART.EQ-NSE  2020-12-31  2691.00  2670.00  2780.00  2763.60     12
#
# [252 rows x 7 columns]

# %%
k=0
month=1
close=[]
while(k<=len(df)):
    week_count=0
    for i,j in df.iterrows(): 
        if(df.loc[i,'Month']==month):
            if(df.loc[i,'Month']<12):
                if(df.loc[i,'Date/Time'].weekday()==4 or df.loc[i+1,'Month']==month+1):
                    print(df.loc[i,'Date/Time'])
                    close.append(df.loc[i,'Close'])
                    week_count+=1
                    print("Week count",week_count)
                    #print(k)
                    k+=1
                elif(df.loc[i,'Date/Time'].weekday()==3):
                    if(df.loc[i+1,'Date/Time'].weekday()==4):
                        pass
                    else:
                        print(df.loc[i,'Date/Time'])
                        close.append(df.loc[i,'Close'])
                        week_count+=1
                        print("week Count",week_count)
                        k+=1
            if(df.loc[i,'Month']==12):
                if(df.loc[i,'Date/Time'].weekday()==4 or i==251):
                    print(df.loc[i,'Date/Time'])
                    close.append(df.loc[i,'Open'])
                    week_count+=1
                    print("Week count",week_count)
                    #print(k)
                    k+=1
                if(df.loc[i,'Date/Time'].weekday()==3 and i<251):
                    if(df.loc[i+1,'Date/Time'].weekday()==4):
                        pass
                    else:
                        print(df.loc[i,'Date/Time'])
                        close.append(df.loc[i,'Close'])
                        week_count+=1
                        print("Week count",week_count)
                        k+=1
                    
    k+=1
    month+=1
# Out:
# 2020-01-03
# Week count 1
# 2020-01-10
# Week count 2
# 2020-01-17
# Week count 3
# 2020-01-24
# Week count 4
# 2020-01-31
# Week count 5
# 2020-02-07
# Week count 1
# 2020-02-14
# Week count 2
# 2020-02-20
# week Count 3
# 2020-02-28
# Week count 4
# 2020-03-06
# Week count 1
# 2020-03-13
# Week count 2
# 2020-03-20
# Week count 3
# 2020-03-27
# Week count 4
# 2020-03-31
# Week count 5
# 2020-04-03
# Week count 1
# 2020-04-09
# week Count 2
# 2020-04-17
# Week count 3
# 2020-04-24
# Week count 4
# 2020-04-30
# Week count 5
# 2020-05-08
# Week count 1
# 2020-05-15
# Week count 2
# 2020-05-22
# Week count 3
# 2020-05-29
# Week count 4
# 2020-06-05
# Week count 1
# 2020-06-12
# Week count 2
# 2020-06-19
# Week count 3
# 2020-06-26
# Week count 4
# 2020-06-30
# Week count 5
# 2020-07-03
# Week count 1
# 2020-07-10
# Week count 2
# 2020-07-17
# Week count 3
# 2020-07-24
# Week count 4
# 2020-07-31
# Week count 5
# 2020-08-07
# Week count 1
# 2020-08-14
# Week count 2
# 2020-08-21
# Week count 3
# 2020-08-28
# Week count 4
# 2020-08-31
# Week count 5
# 2020-09-04
# Week count 1
# 2020-09-11
# Week count 2
# 2020-09-18
# Week count 3
# 2020-09-25
# Week count 4
# 2020-09-30
# Week count 5
# 2020-10-01
# week Count 1
# 2020-10-09
# Week count 2
# 2020-10-16
# Week count 3
# 2020-10-23
# Week count 4
# 2020-10-30
# Week count 5
# 2020-11-06
# Week count 1
# 2020-11-13
# Week count 2
# 2020-11-20
# Week count 3
# 2020-11-27
# Week count 4
# 2020-12-04
# Week count 1
# 2020-12-11
# Week count 2
# 2020-12-18
# Week count 3
# 2020-12-24
# Week count 4
# 2020-12-31
# Week count 5

# %%
print(len(close))
print(close)
# Out:
# 57
# [1843.55, 1876.95, 1990.55, 1948.6, 2133.95, 2287.2, 2408.35, 2462.65, 2323.95, 2242.15, 2101.0, 1916.1, 2079.7, 2187.5, 2066.95, 2392.65, 2212.1, 2310.5, 2383.65, 2255.0, 2333.8, 2398.3, 2269.35, 2499.0, 2397.8, 2363.15, 2294.4, 2317.15, 2290.15, 2322.7, 1989.75, 2031.4, 2063.45, 2138.4, 2178.0, 2259.45, 2319.4, 2251.25, 2251.45, 2239.35, 2149.05, 2102.7, 2203.15, 2184.8, 2057.6, 1984.2, 2116.55, 2239.9, 2294.6, 2383.05, 2382.6, 2289.2, 2469.95, 2647.0, 2574.0, 2673.1, 2691.0]

# %%
k=0
month=1
open1=[]
while(k<=len(df)):
    week_count=0
    for i,j in df.iterrows(): 
        if(df.loc[i,'Month']==month):
            if(df.loc[i,'Month']>1):
                if(df.loc[i,'Date/Time'].weekday()==0 or df.loc[i-1,'Month']==month-1):
                    print(df.loc[i,'Date/Time'])
                    open1.append(df.loc[i,'Close'])
                    week_count+=1
                    print("Week count",week_count)
                    #print(k)
                    k+=1
                    
                elif(df.loc[i,'Date/Time'].weekday()==1):
                    if(df.loc[i-1,'Date/Time'].weekday()==0):
                        pass
                    else:
                        print(df.loc[i,'Date/Time'])
                        open1.append(df.loc[i,'Close'])
                        week_count+=1
                        print("week Count",week_count)
                        k+=1
               
            if(df.loc[i,'Month']==1):
                if(df.loc[i,'Date/Time'].weekday()==0 or i==0):
                    print(df.loc[i,'Date/Time'])
                    open1.append(df.loc[i,'Open'])
                    week_count+=1
                    print("Week count",week_count)
                    #print(k)
                    k+=1
    k+=1
    month+=1
# Out:
# 2020-01-01
# Week count 1
# 2020-01-06
# Week count 2
# 2020-01-13
# Week count 3
# 2020-01-20
# Week count 4
# 2020-01-27
# Week count 5
# 2020-02-01
# Week count 1
# 2020-02-03
# Week count 2
# 2020-02-10
# Week count 3
# 2020-02-17
# Week count 4
# 2020-02-24
# Week count 5
# 2020-03-02
# Week count 1
# 2020-03-09
# Week count 2
# 2020-03-16
# Week count 3
# 2020-03-23
# Week count 4
# 2020-03-30
# Week count 5
# 2020-04-01
# Week count 1
# 2020-04-07
# week Count 2
# 2020-04-13
# Week count 3
# 2020-04-20
# Week count 4
# 2020-04-27
# Week count 5
# 2020-05-04
# Week count 1
# 2020-05-11
# Week count 2
# 2020-05-18
# Week count 3
# 2020-05-26
# week Count 4
# 2020-06-01
# Week count 1
# 2020-06-08
# Week count 2
# 2020-06-15
# Week count 3
# 2020-06-22
# Week count 4
# 2020-06-29
# Week count 5
# 2020-07-01
# Week count 1
# 2020-07-06
# Week count 2
# 2020-07-13
# Week count 3
# 2020-07-20
# Week count 4
# 2020-07-27
# Week count 5
# 2020-08-03
# Week count 1
# 2020-08-10
# Week count 2
# 2020-08-17
# Week count 3
# 2020-08-24
# Week count 4
# 2020-08-31
# Week count 5
# 2020-09-01
# Week count 1
# 2020-09-07
# Week count 2
# 2020-09-14
# Week count 3
# 2020-09-21
# Week count 4
# 2020-09-28
# Week count 5
# 2020-10-01
# Week count 1
# 2020-10-05
# Week count 2
# 2020-10-12
# Week count 3
# 2020-10-19
# Week count 4
# 2020-10-26
# Week count 5
# 2020-11-02
# Week count 1
# 2020-11-09
# Week count 2
# 2020-11-17
# week Count 3
# 2020-11-23
# Week count 4
# 2020-12-01
# Week count 1
# 2020-12-07
# Week count 2
# 2020-12-14
# Week count 3
# 2020-12-21
# Week count 4
# 2020-12-28
# Week count 5

# %%
print(len(open1))
print(open1)
# Out:
# 58
# [1849.7, 1827.0, 1925.0, 2000.0, 1945.5, 2072.05, 2131.65, 2483.65, 2339.45, 2389.7, 2228.95, 2145.7, 1996.3, 1820.3, 2114.55, 2082.7, 2170.25, 2273.05, 2256.25, 2323.95, 2281.3, 2313.55, 2306.55, 2283.25, 2305.5, 2459.5, 2365.3, 2350.4, 2290.95, 2289.35, 2323.0, 2233.95, 2019.0, 2026.1, 2093.15, 2116.5, 2189.75, 2250.3, 2251.25, 2241.6, 2261.4, 2162.7, 2097.45, 2108.4, 2184.8, 2110.45, 2002.6, 2094.3, 2144.25, 2205.75, 2325.85, 2432.15, 2360.4, 2426.7, 2526.45, 2671.95, 2682.4, 2678.0]

# %%
for i in range(len(close)):
    print(close[i]-open1[i])
# Out:
# -6.150000000000091
# 49.950000000000045
# 65.54999999999995
# -51.40000000000009
# 188.44999999999982
# 215.14999999999964
# 276.6999999999998
# -21.0
# -15.5
# -147.54999999999973
# -127.94999999999982
# -229.5999999999999
# 83.39999999999986
# 367.20000000000005
# -47.600000000000364
# 309.9500000000003
# 41.84999999999991
# 37.44999999999982
# 127.40000000000009
# -68.94999999999982
# 52.5
# 84.75
# -37.20000000000027
# 215.75
# 92.30000000000018
# -96.34999999999991
# -70.90000000000009
# -33.25
# -0.7999999999997272
# 33.34999999999991
# -333.25
# -202.54999999999973
# 44.44999999999982
# 112.30000000000018
# 84.84999999999991
# 142.94999999999982
# 129.6500000000001
# 0.9499999999998181
# 0.1999999999998181
# -2.25
# -112.34999999999991
# -60.0
# 105.70000000000027
# 76.40000000000009
# -127.20000000000027
# -126.24999999999977
# 113.95000000000027
# 145.5999999999999
# 150.3499999999999
# 177.30000000000018
# 56.75
# -142.95000000000027
# 109.54999999999973
# 220.30000000000018
# 47.55000000000018
# 1.150000000000091
# 8.599999999999909

# %%
x = [1,2,4]
